# %% [markdown]
# # MNIST & Fashion-MNIST — NSI Dynamic Brain
# **Neuron Strain Index**: per-neuron freeze + proportional sprout.
# Experiments: `tau_high` percentile vs absolute · output vs hidden grad tracking.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import time

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1)) # Flatten to 784D
])

print("Downloading MNIST...")
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

def get_task_data(dataset, class_a, class_b, max_samples=3000):
    idx = (dataset.targets == class_a) | (dataset.targets == class_b)
    X = dataset.data[idx].float() / 255.0
    X = X.view(X.size(0), -1)
    y = dataset.targets[idx]
    perm = torch.randperm(X.size(0))[:max_samples]
    return X[perm], y[perm]

tasks_train = [get_task_data(trainset, i*2, i*2+1) for i in range(5)]
tasks_test = [get_task_data(testset, i*2, i*2+1, max_samples=1000) for i in range(5)]
print("Split-MNIST generated (5 sequential tasks).")

print("\nDownloading FashionMNIST...")
fashion_train = torchvision.datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
fashion_test = torchvision.datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

fashion_tasks_train = [get_task_data(fashion_train, i*2, i*2+1) for i in range(5)]
fashion_tasks_test = [get_task_data(fashion_test, i*2, i*2+1, max_samples=1000) for i in range(5)]
print("Split-FashionMNIST generated (5 sequential tasks).")
# Out:
# Using device: cuda
# Downloading MNIST...
# Split-MNIST generated (5 sequential tasks).
#
# Downloading FashionMNIST...
# Split-FashionMNIST generated (5 sequential tasks).

# %% [markdown]
# ## Architecture

# %%
def evaluate(net, tasks_test, idx):
    net.eval()
    accs = []
    with torch.no_grad():
        for i in range(idx+1):
            Xt, yt = tasks_test[i]
            Xt, yt = Xt.to(device), yt.to(device)
            pred = net(Xt)
            mask = torch.ones_like(pred, dtype=torch.bool)
            mask[:, [i*2, i*2+1]] = False
            pred[mask] = -float('inf')
            accs.append((pred.argmax(1)==yt).float().mean().item())
    net.train()
    return accs


class DynamicBrain(nn.Module):
    def __init__(self, input_dim=784, output_dim=10, seed_neurons=10, k_frozen=10, k_plastic=5):
        super().__init__()
        self.input_dim  = input_dim
        self.output_dim = output_dim
        self.k_frozen   = k_frozen
        self.k_plastic  = k_plastic
        n = seed_neurons

        self.hidden_W = nn.Parameter(torch.randn(n, input_dim) * 0.1)
        self.hidden_b = nn.Parameter(torch.zeros(n))
        self.out_W    = nn.Parameter(torch.zeros(output_dim, n))
        self.out_b    = nn.Parameter(torch.zeros(output_dim))

        self.neuron_states  = ['PLASTIC'] * n
        self.active_neurons = n

    def forward(self, x):
        h = F.linear(x, self.hidden_W, self.hidden_b)
        
        frozen_idx  = [i for i, s in enumerate(self.neuron_states) if s == 'FROZEN']
        plastic_idx = [i for i, s in enumerate(self.neuron_states) if s == 'PLASTIC']
        
        mask = torch.zeros_like(h)
        
        if frozen_idx:
            kf = min(self.k_frozen, len(frozen_idx))
            if kf > 0:
                hf = h[:, frozen_idx]
                _, top_idx = hf.topk(kf, dim=1)
                # Scatter 1.0 into mask at the correct global indices
                global_top = torch.tensor(frozen_idx, device=h.device)[top_idx]
                mask.scatter_(1, global_top, 1.0)
                
        if plastic_idx:
            kp = min(self.k_plastic, len(plastic_idx))
            if kp > 0:
                hp = h[:, plastic_idx]
                _, top_idx = hp.topk(kp, dim=1)
                global_top = torch.tensor(plastic_idx, device=h.device)[top_idx]
                mask.scatter_(1, global_top, 1.0)
                
        h = F.relu(h * mask)
        return F.linear(h, self.out_W, self.out_b)

    def zero_frozen_grads(self):
        frozen = [i for i,s in enumerate(self.neuron_states) if s=='FROZEN']
        if frozen:
            if self.hidden_W.grad is not None:
                self.hidden_W.grad[frozen, :] = 0
                self.hidden_b.grad[frozen]    = 0
            # REMOVED out_W.grad zeroing here.
            # We WANT new classes to learn to use frozen features!
            # Past classes are already protected by active-class masking.

    def grow_and_freeze(self, freeze_indices, num_new):
        for i in freeze_indices:
            self.neuron_states[i] = 'FROZEN'
        if num_new <= 0:
            return
        self.active_neurons += num_new
        self.neuron_states.extend(['PLASTIC'] * num_new)
        with torch.no_grad():
            dev = self.out_b.device
            hW = torch.randn(num_new, self.input_dim,  device=dev) * 0.1
            hb = torch.zeros(num_new,                  device=dev)
            oW = torch.zeros(self.output_dim, num_new, device=dev)  # ZERO init prevents corrupting past classes
            self.hidden_W = nn.Parameter(torch.cat([self.hidden_W, hW], 0))
            self.hidden_b = nn.Parameter(torch.cat([self.hidden_b, hb], 0))
            self.out_W    = nn.Parameter(torch.cat([self.out_W,    oW], 1))

print("DynamicBrain defined.")
# Out:
# DynamicBrain defined.

# %% [markdown]
# ## NeuronHealthMonitor

# %%
class NeuronHealthMonitor:
    # Tracks per-neuron health via Neuron Strain Index (NSI).
    #
    # Three EMAs per neuron:
    #   grad_mag[n]     = EMA of ||grad_hidden_W[n]||   (demand)
    #   out_grad_mag[n] = EMA of ||grad_out_W[:,n]||    (output demand)
    #   contribution[n] = EMA of (grad_n . delta_w_n)   (SI: is it helping?)
    #
    # Freeze conditions (after min_age batches, checked every check_interval):
    #   CONVERGED  : grad_mag[n] < tau_low              for patience checks
    #   STRUGGLING : grad_mag[n] > tau_high AND
    #                contribution[n] <= tau_contrib      for patience checks
    #
    # tau_high_mode:
    #   'percentile' -> self-calibrating, adapts as network grows
    #   'absolute'   -> fixed; calibrate from diagnostic cell
    def __init__(self, num_neurons, device='cpu',
                 alpha=0.05,
                 check_interval=20, patience=3, min_age=40,
                 tau_low=0.001,
                 tau_high_mode='percentile',
                 tau_high_pct=0.70,
                 tau_high_abs=None,
                 tau_conflict=0.5,
                 track_output_grads=True):

        self.device           = device
        self.alpha            = alpha
        self.check_interval   = check_interval
        self.patience         = patience
        self.min_age          = min_age
        self.tau_low          = tau_low
        self.tau_high_mode    = tau_high_mode
        self.tau_high_pct     = tau_high_pct
        self.tau_high_abs     = tau_high_abs
        self.tau_conflict      = tau_conflict
        self.track_output_grads = track_output_grads

        self._alloc(num_neurons)
        self.w_prev   = None
        self.batch_no = 0

        # Diagnostics log (filled during training for analysis)
        self.log = []   # list of dicts, one per check_interval

    def _alloc(self, n):
        d = self.device
        self.grad_mag      = torch.zeros(n, device=d)
        self.out_grad_mag  = torch.zeros(n, device=d)
        self.conflict      = torch.zeros(n, device=d)
        self.grad_vec      = None
        self.age           = torch.zeros(n, dtype=torch.long, device=d)
        self.conv_count    = torch.zeros(n, dtype=torch.long, device=d)
        self.str_count     = torch.zeros(n, dtype=torch.long, device=d)
        self.n             = n

    def expand(self, num_new):
        d = self.device
        def _cat(t, m=None):
            if m is None:
                return torch.cat([t, torch.zeros(num_new, device=d)])
            return torch.cat([t, torch.zeros(num_new, dtype=m, device=d)])
        self.grad_mag     = _cat(self.grad_mag)
        self.out_grad_mag = _cat(self.out_grad_mag)
        self.conflict     = _cat(self.conflict)
        if self.grad_vec is not None:
            self.grad_vec = torch.cat([self.grad_vec, torch.zeros(num_new, self.grad_vec.size(1), device=d)])
        self.age          = _cat(self.age,        torch.long)
        self.conv_count   = _cat(self.conv_count, torch.long)
        self.str_count    = _cat(self.str_count,  torch.long)
        self.n           += num_new

    def pre_step(self, net):
        # Call BEFORE optimizer.step() to snapshot weights.
        self.w_prev = net.hidden_W.data.clone()

    def post_step(self, net, hidden_grad, out_grad=None):
        # Call AFTER optimizer.step() to update EMAs.
        delta = net.hidden_W.data - self.w_prev   # actual weight movement
        a     = self.alpha

        for n in range(self.n):
            if net.neuron_states[n] == 'FROZEN':
                continue
            gn     = hidden_grad[n]
            dn     = delta[n]
            gm     = gn.norm().item()
            if self.grad_vec is None:
                self.grad_vec = torch.zeros_like(hidden_grad)
                
            self.grad_mag[n] = (1-a)*self.grad_mag[n] + a*gm
            self.grad_vec[n] = (1-a)*self.grad_vec[n] + a*gn
            
            # Conflict Index: 1.0 - (||ema_grad_vec|| / ema_grad_mag)
            # High conflict (~1.0) means gradients are oscillating/pulling in different directions
            # Low conflict (~0.0) means gradients point in a consistent direction
            vec_mag = self.grad_vec[n].norm().item()
            conf = 1.0 - (vec_mag / (self.grad_mag[n].item() + 1e-8))
            self.conflict[n] = conf

            if self.track_output_grads and out_grad is not None:
                ogm = out_grad[:, n].norm().item()
                self.out_grad_mag[n] = (1-a)*self.out_grad_mag[n] + a*ogm

            self.age[n] += 1
        self.batch_no += 1

    def _tau_high(self, plastic_ids):
        if self.tau_high_mode == 'absolute':
            return self.tau_high_abs
        # percentile mode: self-calibrating
        if len(plastic_ids) < 2:
            return self.grad_mag[plastic_ids].max().item() if plastic_ids else 1e9
        gm = self.grad_mag[plastic_ids]
        return torch.quantile(gm, self.tau_high_pct).item()

    def check_health(self, net):
        # Called every check_interval batches.
        # Returns (freeze_indices, n_sprout, log_dict).

        plastic = [i for i,s in enumerate(net.neuron_states)
                   if s == 'PLASTIC' and self.age[i] >= self.min_age]
        to_freeze, n_sprout = [], 0

        tau_h = self._tau_high(plastic)

        for n in plastic:
            gm   = self.grad_mag[n].item()
            conf = self.conflict[n].item()
            ogm  = self.out_grad_mag[n].item()

            converged   = gm < self.tau_low
            struggling  = gm > tau_h and conf >= self.tau_conflict

            if converged:
                self.conv_count[n] += 1
                self.str_count[n]   = 0
                if self.conv_count[n] >= self.patience:
                    to_freeze.append(n)          # converged: freeze, no sprout
            elif struggling:
                self.str_count[n] += 1
                self.conv_count[n]  = 0
                if self.str_count[n] >= self.patience:
                    to_freeze.append(n)          # struggling: freeze + sprout
                    n_sprout += 1
            else:
                self.conv_count[n] = 0
                self.str_count[n]  = 0

        # Diagnostic snapshot
        snap = {
            'batch': self.batch_no,
            'tau_high': tau_h,
            'tau_high_mode': self.tau_high_mode,
            'n_plastic': len(plastic),
            'n_frozen': sum(1 for s in net.neuron_states if s=='FROZEN'),
            'n_freeze_now': len(to_freeze),
            'n_sprout_now': n_sprout,
            'grad_mag': self.grad_mag.cpu().tolist(),
            'out_grad_mag': self.out_grad_mag.cpu().tolist(),
            'conflict': self.conflict.cpu().tolist(),
        }
        self.log.append(snap)
        plastic_count = net.neuron_states.count('PLASTIC')
        plastic_remaining = plastic_count - len(to_freeze)
        min_p = net.k_plastic
        if plastic_remaining + n_sprout < min_p:
            n_sprout += min_p - (plastic_remaining + n_sprout)
        return to_freeze, n_sprout, snap

print("NeuronHealthMonitor defined.")
# Out:
# NeuronHealthMonitor defined.

# %% [markdown]
# ## Step 1 — Diagnostic: Calibrate Thresholds (run this first!)

# %%
# ── DIAGNOSTIC: train on T1 only, plot per-neuron metrics ────────────
# Use this to calibrate tau_low and tau_high_abs before the full run.

diag_net = DynamicBrain(input_dim=784, seed_neurons=20).to(device)
diag_opt = torch.optim.Adam(diag_net.parameters(), lr=0.003)
diag_crit = nn.CrossEntropyLoss()

diag_mon = NeuronHealthMonitor(
    num_neurons=20, device=device,
    alpha=0.05, check_interval=20, patience=99,  # patience=99: never actually freeze
    min_age=10, tau_low=1e-4, tau_high_mode='percentile', tau_high_pct=0.70,
    tau_conflict=0.5, track_output_grads=True
)

X_t1, y_t1 = tasks_train[0]
active_classes = [0, 1]
diag_logs = []

for epoch in range(4):
    for i in range(0, X_t1.size(0), 64):
        bx = X_t1[i:i+64].to(device)
        by = y_t1[i:i+64].to(device)
        if bx.size(0) < 16:
            continue

        diag_net.zero_grad()
        pred = diag_net(bx)
        lm   = torch.ones_like(pred, dtype=torch.bool)
        lm[:, active_classes] = False
        pred[lm] = -float('inf')
        loss = diag_crit(pred, by)
        loss.backward()

        hidden_grad = diag_net.hidden_W.grad.clone()
        out_grad    = diag_net.out_W.grad.clone()

        diag_mon.pre_step(diag_net)
        diag_net.zero_frozen_grads()
        diag_opt.step()
        diag_mon.post_step(diag_net, hidden_grad, out_grad)

        if diag_mon.batch_no % 20 == 0:
            _, _, snap = diag_mon.check_health(diag_net)
            diag_logs.append(snap)

batches = [s['batch'] for s in diag_logs]
gm_arr  = np.array([s['grad_mag'] for s in diag_logs])       # (steps, neurons)
og_arr  = np.array([s['out_grad_mag'] for s in diag_logs])
cf_arr  = np.array([s['conflict'] for s in diag_logs])

fig, axes = plt.subplots(3, 1, figsize=(14, 12))

# Panel 1: hidden grad_mag per neuron
for n in range(20):
    axes[0].plot(batches, gm_arr[:, n], alpha=0.5)
axes[0].set_title('Hidden grad_mag per neuron (EMA)', fontsize=13)
axes[0].set_ylabel('||grad_hidden_W[n]||')
axes[0].axhline(0.001, color='red',    linestyle='--', label='tau_low candidate')
axes[0].axhline(gm_arr[-5:, :].mean()*2, color='orange',
                linestyle='--', label='~2x converged mean')
axes[0].legend(); axes[0].grid(alpha=0.3)

# Panel 2: output grad_mag per neuron
for n in range(20):
    axes[1].plot(batches, og_arr[:, n], alpha=0.5)
axes[1].set_title('Output grad_mag per neuron (EMA)  [track_output_grads=True]', fontsize=13)
axes[1].set_ylabel('||grad_out_W[:,n]||')
axes[1].grid(alpha=0.3)

# Panel 3: SI contribution per neuron
for n in range(20):
    axes[2].plot(batches, cf_arr[:, n], alpha=0.5)
axes[2].axhline(0.5, color='red', linestyle='--', label='tau_conflict=0.5 boundary')
axes[2].set_title('Gradient Conflict Index per neuron', fontsize=13)
axes[2].set_ylabel('Conflict (0=consistent, 1=oscillating)')
axes[2].set_xlabel('batch')
axes[2].legend(); axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('nsi_diagnostic.png', dpi=150, bbox_inches='tight')
plt.show()

# Print summary statistics to guide threshold selection
late = gm_arr[-10:, :]   # last 10 checkpoints
print("=== Diagnostic Summary (last 10 checks) ===")
print(f"  hidden grad_mag  | mean={late.mean():.5f}  p10={np.percentile(late,10):.5f}  p70={np.percentile(late,70):.5f}  max={late.max():.5f}")
print(f"  -> tau_low candidate  : {np.percentile(late,10):.5f}  (p10 of converged neurons)")
print(f"  -> tau_high_abs cand. : {np.percentile(late,70):.5f}  (p70 = top 30% = struggling)")
print(f"  conflict         | mean={cf_arr[-10:].mean():.5f}  fraction>=0.5: {(cf_arr[-10:]>=0.5).mean():.2f}")
# Out:
# === Diagnostic Summary (last 10 checks) ===
#   hidden grad_mag  | mean=0.00362  p10=0.00000  p70=0.00398  max=0.02932
#   -> tau_low candidate  : 0.00000  (p10 of converged neurons)
#   -> tau_high_abs cand. : 0.00398  (p70 = top 30% = struggling)
#   conflict         | mean=0.45812  fraction>=0.5: 0.48

# %% [markdown]
# ## Step 2 — Full NSI Training

# %%
# ── FULL TRAINING: NSI Dynamic Brain ─────────────────────────────────
# Run the diagnostic cell first to calibrate tau_low / tau_high_abs!
# Then adjust the config below accordingly.

CFG = dict(
    seed_neurons    = 10,
    lr              = 0.003,
    epochs_per_task = 50,
    batch_size      = 64,
    # NeuronHealthMonitor settings
    alpha           = 0.05,
    check_interval  = 20,
    patience        = 3,
    min_age         = 40,
    tau_low         = 0.025,        # UPDATED from diagnostic        # calibrate from diagnostic
    tau_high_mode   = 'percentile', # 'percentile' or 'absolute'
    tau_high_pct    = 0.70,         # used when mode='percentile'
    tau_high_abs    = None,         # used when mode='absolute' (set from diagnostic)
    tau_conflict    = 0.5,          # NEW: conflict threshold
    track_output_grads = True,
)

net  = DynamicBrain(input_dim=784, seed_neurons=CFG['seed_neurons'], k_frozen=5, k_plastic=5).to(device)
opt  = torch.optim.Adam(net.parameters(), lr=CFG['lr'])
crit = nn.CrossEntropyLoss()

mon = NeuronHealthMonitor(
    num_neurons        = CFG['seed_neurons'],
    device             = device,
    alpha              = CFG['alpha'],
    check_interval     = CFG['check_interval'],
    patience           = CFG['patience'],
    min_age            = CFG['min_age'],
    tau_low            = CFG['tau_low'],
    tau_high_mode      = CFG['tau_high_mode'],
    tau_high_pct       = CFG['tau_high_pct'],
    tau_high_abs       = CFG['tau_high_abs'],
    tau_conflict       = CFG['tau_conflict'],
    track_output_grads = CFG['track_output_grads'],
)

dynamic_accs   = []
growth_events  = []    # [(batch, freeze_indices, n_sprout)]
total_batches  = 0

print("Training NSI Dynamic Brain on Split CIFAR-10...")
for task_idx, (X_tr_, y_tr_) in enumerate(tasks_train):
    print(f"\n--- Task {task_idx+1}/5  (Task {task_idx+1}) ---")
    active_classes = [task_idx*2, task_idx*2+1]

    for epoch in range(CFG['epochs_per_task']):
        for i in range(0, X_tr_.size(0), CFG['batch_size']):
            bx = X_tr_[i:i+CFG['batch_size']].to(device)
            by = y_tr_[i:i+CFG['batch_size']].to(device)
            if bx.size(0) < 16:
                continue

            # Forward
            net.zero_grad()
            pred = net(bx)
            lm   = torch.ones_like(pred, dtype=torch.bool)
            lm[:, active_classes] = False
            pred[lm] = -float('inf')
            loss = crit(pred, by)
            loss.backward()

            # Capture grads BEFORE optimizer step
            hg = net.hidden_W.grad.clone()
            og = net.out_W.grad.clone() if CFG['track_output_grads'] else None

            # Snapshot weights, zero frozen, step
            mon.pre_step(net)
            net.zero_frozen_grads()
            opt.step()
            mon.post_step(net, hg, og)

            # Periodic health check
            if mon.batch_no % CFG['check_interval'] == 0:
                to_freeze, n_sprout, snap = mon.check_health(net)

                if to_freeze or n_sprout > 0:
                    n_frozen_total = sum(1 for s in net.neuron_states if s=='FROZEN')
                    print(f"  Batch {total_batches:04d} | "
                          f"freeze {len(to_freeze)} | "
                          f"sprout {n_sprout} | "
                          f"total {net.active_neurons+n_sprout} neurons")
                    net.grow_and_freeze(to_freeze, n_sprout)
                    mon.expand(n_sprout)
                    opt = torch.optim.Adam(net.parameters(), lr=CFG['lr'])
                    growth_events.append((total_batches, to_freeze, n_sprout))

            total_batches += 1

    accs = evaluate(net, tasks_test, task_idx)
    dynamic_accs.append(accs)
    n_frozen  = sum(1 for s in net.neuron_states if s=='FROZEN')
    n_plastic = sum(1 for s in net.neuron_states if s=='PLASTIC')
    print(f"End of Task {task_idx+1} | frozen={n_frozen} plastic={n_plastic} total={net.active_neurons}")
    for j, a in enumerate(accs):
        print(f"  Task {j+1}: {a*100:.1f}%")

print(f"\nFinal: {net.active_neurons} neurons  ({sum(1 for s in net.neuron_states if s=='FROZEN')} frozen)")
print(f"Growth events: {len(growth_events)}")
# Out:
# Training NSI Dynamic Brain on Split CIFAR-10...
#
# --- Task 1/5  (Task 1) ---
#   Batch 0079 | freeze 6 | sprout 1 | total 11 neurons
#   Batch 0099 | freeze 4 | sprout 4 | total 15 neurons
#   Batch 0159 | freeze 1 | sprout 1 | total 16 neurons
#   Batch 0179 | freeze 4 | sprout 4 | total 20 neurons
#   Batch 0239 | freeze 1 | sprout 1 | total 21 neurons
#   Batch 0259 | freeze 4 | sprout 4 | total 25 neurons
#   Batch 0319 | freeze 1 | sprout 1 | total 26 neurons
#   Batch 0339 | freeze 4 | sprout 4 | total 30 neurons
#   Batch 0399 | freeze 1 | sprout 1 | total 31 neurons
#   Batch 0419 | freeze 4 | sprout 4 | total 35 neurons
# End of Task 1 | frozen=150 plastic=5 total=155
#   Task 1: 100.0%
#
# --- Task 2/5  (Task 2) ---
#   Batch 2439 | freeze 1 | sprout 1 | total 156 neurons
#   Batch 2459 | freeze 1 | sprout 1 | total 157 neurons
#   Batch 2519 | freeze 2 | sprout 2 | total 159 neurons
#   Batch 2539 | freeze 1 | sprout 1 | total 160 neurons
#   Batch 2559 | freeze 1 | sprout 1 | total 161 neurons
#   Batch 2599 | freeze 1 | sprout 1 | total 162 neurons
#   Batch 2619 | freeze 2 | sprout 2 | total 164 neurons
#   Batch 2639 | freeze 1 | sprout 1 | total 165 neurons
#   Batch 2679 | freeze 2 | sprout 2 | total 167 neurons
#   Batch 2699 | freeze 2 | sprout 2 | total 169 neurons
#   Batch 2719 | freeze 1 | sprout 1 | total 170 neurons
#   Batch 2759 | freeze 2 | sprout 2 | total 172 neurons
#   Batch 2779 | freeze 2 | sprout 2 | total 174 neurons
#   Batch 2799 | freeze 1 | sprout 1 | total 175 neurons
#   Batch 2839 | freeze 2 | sprout 2 | total 177 neurons
#   Batch 2859 | freeze 2 | sprout 2 | total 179 neurons
#   Batch 2919 | freeze 3 | sprout 3 | total 182 neurons
#   Batch 2939 | freeze 2 | sprout 2 | total 184 neurons
#   Batch 2999 | freeze 3 | sprout 3 | total 187 neurons
#   Batch 3019 | freeze 2 | sprout 2 | total 189 neurons
#   Batch 3079 | freeze 3 | sprout 3 | total 192 neurons
#   Batch 3099 | freeze 2 | sprout 2 | total 194 neurons
#   Batch 3159 | freeze 3 | sprout 3 | total 197 neurons
#   Batch 3179 | freeze 2 | sprout 2 | total 199 neurons
#   Batch 3239 | freeze 3 | sprout 3 | total 202 neurons
#   Batch 3259 | freeze 2 | sprout 2 | total 204 neurons
#   Batch 3319 | freeze 3 | sprout 3 | total 207 neurons
#   Batch 3379 | freeze 1 | sprout 1 | total 208 neurons
#   Batch 3399 | freeze 4 | sprout 4 | total 212 neurons
#   Batch 3459 | freeze 1 | sprout 1 | total 213 neurons
#   Batch 3479 | freeze 4 | sprout 4 | total 217 neurons
#   Batch 3539 | freeze 1 | sprout 1 | total 218 neurons
#   Batch 3559 | freeze 4 | sprout 4 | total 222 neurons
#   Batch 3619 | freeze 1 | sprout 1 | total 223 neurons
#   Batch 3639 | freeze 4 | sprout 4 | total 227 neurons
#   Batch 3699 | freeze 1 | sprout 1 | total 228 neurons
#   Batch 3719 | freeze 4 | sprout 4 | total 232 neurons
#   Batch 3779 | freeze 1 | sprout 1 | total 233 neurons
#   Batch 3799 | freeze 3 | sprout 3 | total 236 neurons
#   Batch 3839 | freeze 1 | sprout 1 | total 237 neurons
#   Batch 3859 | freeze 1 | sprout 1 | total 238 neurons
#   Batch 3879 | freeze 3 | sprout 3 | total 241 neurons
#   Batch 3919 | freeze 1 | sprout 1 | total 242 neurons
#   Batch 3939 | freeze 1 | sprout 1 | total 243 neurons
#   Batch 3959 | freeze 2 | sprout 2 | total 245 neurons
#   Batch 3999 | freeze 1 | sprout 1 | total 246 neurons
#   Batch 5579 | freeze 2 | sprout 2 | total 337 neurons
#   Batch 5599 | freeze 3 | sprout 3 | total 340 neurons
#   Batch 5659 | freeze 2 | sprout 2 | total 342 neurons
#   Batch 5679 | freeze 3 | sprout 3 | total 345 neurons
#   Batch 5739 | freeze 2 | sprout 2 | total 347 neurons
#   Batch 5759 | freeze 3 | sprout 3 | total 350 neurons
#   Batch 5819 | freeze 2 | sprout 2 | total 352 neurons
#   Batch 5839 | freeze 3 | sprout 3 | total 355 neurons
#   Batch 5899 | freeze 2 | sprout 2 | total 357 neurons
#   Batch 5919 | freeze 3 | sprout 3 | total 360 neurons
#   Batch 5979 | freeze 2 | sprout 2 | total 362 neurons
#   Batch 5999 | freeze 3 | sprout 3 | total 365 neurons
#   Batch 6059 | freeze 2 | sprout 2 | total 367 neurons
#   Batch 6079 | freeze 3 | sprout 3 | total 370 neurons
#   Batch 6139 | freeze 2 | sprout 2 | total 372 neurons
#   Batch 6159 | freeze 3 | sprout 3 | total 375 neurons
#   Batch 6219 | freeze 2 | sprout 2 | total 377 neurons
#   Batch 6239 | freeze 3 | sprout 3 | total 380 neurons
#   Batch 6299 | freeze 2 | sprout 2 | total 382 neurons
#   Batch 6319 | freeze 3 | sprout 3 | total 385 neurons
#   Batch 6379 | freeze 2 | sprout 2 | total 387 neurons
#   Batch 6399 | freeze 3 | sprout 3 | total 390 neurons
#   Batch 6459 | freeze 2 | sprout 2 | total 392 neurons
#   Batch 6479 | freeze 3 | sprout 3 | total 395 neurons
#   Batch 6539 | freeze 2 | sprout 2 | total 397 neurons
#   Batch 6559 | freeze 3 | sprout 3 | total 400 neurons
#   Batch 6619 | freeze 2 | sprout 2 | total 402 neurons
#   Batch 6639 | freeze 3 | sprout 3 | total 405 neurons
#   Batch 6699 | freeze 2 | sprout 2 | total 407 neurons
#   Batch 6719 | freeze 3 | sprout 3 | total 410 neurons
#   Batch 6779 | freeze 2 | sprout 2 | total 412 neurons
#   Batch 6799 | freeze 3 | sprout 3 | total 415 neurons
#   Batch 6859 | freeze 2 | sprout 2 | total 417 neurons
#   Batch 6879 | freeze 3 | sprout 3 | total 420 neurons
#   Batch 6939 | freeze 2 | sprout 2 | total 422 neurons
#   Batch 6959 | freeze 3 | sprout 3 | total 425 neurons
#   Batch 7019 | freeze 2 | sprout 2 | total 427 neurons
#   Batch 7039 | freeze 3 | sprout 3 | total 430 neurons
# End of Task 3 | frozen=425 plastic=5 total=430
#   Task 1: 100.0%
#   Task 2: 90.7%
#   Task 3: 98.7%
#
# --- Task 4/5  (Task 4) ---
#   Batch 7099 | freeze 1 | sprout 1 | total 431 neurons
#   Batch 7119 | freeze 1 | sprout 1 | total 432 neurons
#   Batch 7139 | freeze 3 | sprout 3 | total 435 neurons
#   Batch 7179 | freeze 1 | sprout 1 | total 436 neurons
#   Batch 7199 | freeze 1 | sprout 1 | total 437 neurons
#   Batch 7219 | freeze 3 | sprout 3 | total 440 neurons
#   Batch 7259 | freeze 1 | sprout 1 | total 441 neurons
#   Batch 8559 | freeze 1 | sprout 1 | total 522 neurons
#   Batch 8579 | freeze 3 | sprout 3 | total 525 neurons
#   Batch 8619 | freeze 1 | sprout 1 | total 526 neurons
#   Batch 8639 | freeze 1 | sprout 1 | total 527 neurons
#   Batch 8659 | freeze 3 | sprout 3 | total 530 neurons
#   Batch 8699 | freeze 1 | sprout 1 | total 531 neurons
#   Batch 8719 | freeze 1 | sprout 1 | total 532 neurons
#   Batch 8739 | freeze 3 | sprout 3 | total 535 neurons
#   Batch 8779 | freeze 1 | sprout 1 | total 536 neurons
#   Batch 8799 | freeze 1 | sprout 1 | total 537 neurons
#   Batch 8819 | freeze 3 | sprout 3 | total 540 neurons
#   Batch 8859 | freeze 1 | sprout 1 | total 541 neurons
#   Batch 8879 | freeze 1 | sprout 1 | total 542 neurons
#   Batch 8899 | freeze 3 | sprout 3 | total 545 neurons
#   Batch 8939 | freeze 1 | sprout 1 | total 546 neurons
#   Batch 8959 | freeze 1 | sprout 1 | total 547 neurons
#   Batch 8979 | freeze 3 | sprout 3 | total 550 neurons
#   Batch 9019 | freeze 1 | sprout 1 | total 551 neurons
#   Batch 9039 | freeze 1 | sprout 1 | total 552 neurons
#   Batch 9059 | freeze 3 | sprout 3 | total 555 neurons
#   Batch 9099 | freeze 1 | sprout 1 | total 556 neurons
#   Batch 9119 | freeze 1 | sprout 1 | total 557 neurons
#   Batch 9139 | freeze 3 | sprout 3 | total 560 neurons
#   Batch 9179 | freeze 1 | sprout 1 | total 561 neurons
#   Batch 9199 | freeze 1 | sprout 1 | total 562 neurons
#   Batch 9219 | freeze 3 | sprout 3 | total 565 neurons
#   Batch 9259 | freeze 1 | sprout 1 | total 566 neurons
#   Batch 9279 | freeze 1 | sprout 1 | total 567 neurons
#   Batch 9299 | freeze 3 | sprout 3 | total 570 neurons
#   Batch 9339 | freeze 1 | sprout 1 | total 571 neurons
#   Batch 9359 | freeze 1 | sprout 1 | total 572 neurons
#   Batch 9379 | freeze 3 | sprout 3 | total 575 neurons
# End of Task 4 | frozen=570 plastic=5 total=575
#   Task 1: 100.0%
#   Task 2: 89.2%
#   Task 3: 97.9%
#   Task 4: 99.5%
#
# --- Task 5/5  (Task 5) ---
#   Batch 9419 | freeze 1 | sprout 1 | total 576 neurons
#   Batch 9479 | freeze 1 | sprout 1 | total 577 neurons
#   Batch 9539 | freeze 1 | sprout 1 | total 578 neurons
#   Batch 9559 | freeze 2 | sprout 2 | total 580 neurons
#   Batch 9619 | freeze 2 | sprout 2 | total 582 neurons
#   Batch 9639 | freeze 3 | sprout 3 | total 585 neurons
#   Batch 9699 | freeze 2 | sprout 2 | total 587 neurons
#   Batch 9719 | freeze 2 | sprout 2 | total 589 neurons
#   Batch 9759 | freeze 1 | sprout 1 | total 590 neurons
#   Batch 9779 | freeze 2 | sprout 2 | total 592 neurons
#   Batch 9799 | freeze 2 | sprout 2 | total 594 neurons
#   Batch 9839 | freeze 1 | sprout 1 | total 595 neurons
#   Batch 9859 | freeze 1 | sprout 1 | total 596 neurons
#   Batch 11399 | freeze 3 | sprout 3 | total 682 neurons
#   Batch 11419 | freeze 1 | sprout 1 | total 683 neurons
#   Batch 11479 | freeze 4 | sprout 4 | total 687 neurons
#   Batch 11499 | freeze 1 | sprout 1 | total 688 neurons
#   Batch 11559 | freeze 3 | sprout 3 | total 691 neurons
#   Batch 11579 | freeze 1 | sprout 1 | total 692 neurons
#   Batch 11599 | freeze 1 | sprout 1 | total 693 neurons
#   Batch 11639 | freeze 3 | sprout 3 | total 696 neurons
#   Batch 11659 | freeze 1 | sprout 1 | total 697 neurons
#   Batch 11679 | freeze 1 | sprout 1 | total 698 neurons
#   Batch 11719 | freeze 2 | sprout 2 | total 700 neurons
#   Batch 11739 | freeze 1 | sprout 1 | total 701 neurons
# End of Task 5 | frozen=696 plastic=5 total=701
#   Task 1: 99.6%
#   Task 2: 86.9%
#   Task 3: 97.8%
#   Task 4: 99.5%
#   Task 5: 95.8%
#
# Final: 701 neurons  (696 frozen)
# Growth events: 349

# %% [markdown]
# ## Step 3 — Analysis & Insight Plots

# %% [markdown]
# ## 5. Run Experiment: Fashion-MNIST

# %%
# ── FULL TRAINING: NSI Dynamic Brain ─────────────────────────────────
# Run the diagnostic cell first to calibrate tau_low / tau_high_abs!
# Then adjust the config below accordingly.

CFG = dict(
    seed_neurons    = 10,
    lr              = 0.003,
    epochs_per_task = 50,
    batch_size      = 64,
    # NeuronHealthMonitor settings
    alpha           = 0.05,
    check_interval  = 20,
    patience        = 3,
    min_age         = 40,
    tau_low         = 0.025,        # UPDATED from diagnostic        # calibrate from diagnostic
    tau_high_mode   = 'percentile', # 'percentile' or 'absolute'
    tau_high_pct    = 0.70,         # used when mode='percentile'
    tau_high_abs    = None,         # used when mode='absolute' (set from diagnostic)
    tau_conflict    = 0.5,          # NEW: conflict threshold
    track_output_grads = True,
)

net  = DynamicBrain(input_dim=784, seed_neurons=CFG['seed_neurons'], k_frozen=5, k_plastic=5).to(device)
opt  = torch.optim.Adam(net.parameters(), lr=CFG['lr'])
crit = nn.CrossEntropyLoss()

mon = NeuronHealthMonitor(
    num_neurons        = CFG['seed_neurons'],
    device             = device,
    alpha              = CFG['alpha'],
    check_interval     = CFG['check_interval'],
    patience           = CFG['patience'],
    min_age            = CFG['min_age'],
    tau_low            = CFG['tau_low'],
    tau_high_mode      = CFG['tau_high_mode'],
    tau_high_pct       = CFG['tau_high_pct'],
    tau_high_abs       = CFG['tau_high_abs'],
    tau_conflict       = CFG['tau_conflict'],
    track_output_grads = CFG['track_output_grads'],
)

dynamic_accs   = []
growth_events  = []    # [(batch, freeze_indices, n_sprout)]
total_batches  = 0

print("Training NSI Dynamic Brain on Split Fashion-MNIST...")
for task_idx, (X_tr_, y_tr_) in enumerate(fashion_tasks_train):
    print(f"\n--- Task {task_idx+1}/5  (Task {task_idx+1}) ---")
    active_classes = [task_idx*2, task_idx*2+1]

    for epoch in range(CFG['epochs_per_task']):
        for i in range(0, X_tr_.size(0), CFG['batch_size']):
            bx = X_tr_[i:i+CFG['batch_size']].to(device)
            by = y_tr_[i:i+CFG['batch_size']].to(device)
            if bx.size(0) < 16:
                continue

            # Forward
            net.zero_grad()
            pred = net(bx)
            lm   = torch.ones_like(pred, dtype=torch.bool)
            lm[:, active_classes] = False
            pred[lm] = -float('inf')
            loss = crit(pred, by)
            loss.backward()

            # Capture grads BEFORE optimizer step
            hg = net.hidden_W.grad.clone()
            og = net.out_W.grad.clone() if CFG['track_output_grads'] else None

            # Snapshot weights, zero frozen, step
            mon.pre_step(net)
            net.zero_frozen_grads()
            opt.step()
            mon.post_step(net, hg, og)

            # Periodic health check
            if mon.batch_no % CFG['check_interval'] == 0:
                to_freeze, n_sprout, snap = mon.check_health(net)

                if to_freeze or n_sprout > 0:
                    n_frozen_total = sum(1 for s in net.neuron_states if s=='FROZEN')
                    print(f"  Batch {total_batches:04d} | "
                          f"freeze {len(to_freeze)} | "
                          f"sprout {n_sprout} | "
                          f"total {net.active_neurons+n_sprout} neurons")
                    net.grow_and_freeze(to_freeze, n_sprout)
                    mon.expand(n_sprout)
                    opt = torch.optim.Adam(net.parameters(), lr=CFG['lr'])
                    growth_events.append((total_batches, to_freeze, n_sprout))

            total_batches += 1

    accs = evaluate(net, fashion_tasks_test, task_idx)
    dynamic_accs.append(accs)
    n_frozen  = sum(1 for s in net.neuron_states if s=='FROZEN')
    n_plastic = sum(1 for s in net.neuron_states if s=='PLASTIC')
    print(f"End of Task {task_idx+1} | frozen={n_frozen} plastic={n_plastic} total={net.active_neurons}")
    for j, a in enumerate(accs):
        print(f"  Task {j+1}: {a*100:.1f}%")

print(f"\nFinal: {net.active_neurons} neurons  ({sum(1 for s in net.neuron_states if s=='FROZEN')} frozen)")
print(f"Growth events: {len(growth_events)}")
# Out:
# Training NSI Dynamic Brain on Split Fashion-MNIST...
#
# --- Task 1/5  (Task 1) ---
#   Batch 0079 | freeze 7 | sprout 3 | total 13 neurons
#   Batch 0139 | freeze 1 | sprout 1 | total 14 neurons
#   Batch 0159 | freeze 4 | sprout 3 | total 17 neurons
#   Batch 0199 | freeze 1 | sprout 1 | total 18 neurons
#   Batch 0219 | freeze 1 | sprout 1 | total 19 neurons
#   Batch 0239 | freeze 3 | sprout 3 | total 22 neurons
#   Batch 0279 | freeze 1 | sprout 1 | total 23 neurons
#   Batch 0299 | freeze 1 | sprout 1 | total 24 neurons
#   Batch 0319 | freeze 3 | sprout 3 | total 27 neurons
#   Batch 0359 | freeze 1 | sprout 1 | total 28 neurons
#   Batch 0379 | freeze 1 | sprout 1 | total 29 neurons
#   Batch 0399 | freeze 3 | sprout 3 | total 32 neurons
#   Batch 0439 | freeze 1 | sprout 1 | total 33 neurons
#   Batch 0459 | freeze 1 | sprout 1 | total 34 neurons
#   Batch 0479 | freeze 3 | sprout 3 | total 37 neurons
#   Batch 0519 | freeze 1 | sprout 1 | total 38 neurons
#   Batch 0539 | freeze 1 | sprout 1 | total 39 neurons
#   Batch 0559 | freeze 3 | sprout 3 | total 42 neurons
#   Batch 0599 | freeze 1 | sprout 1 | total 43 neurons
#   Batch 1899 | freeze 1 | sprout 1 | total 124 neurons
#   Batch 1919 | freeze 3 | sprout 3 | total 127 neurons
#   Batch 1959 | freeze 1 | sprout 1 | total 128 neurons
#   Batch 1979 | freeze 1 | sprout 1 | total 129 neurons
#   Batch 1999 | freeze 3 | sprout 3 | total 132 neurons
#   Batch 2039 | freeze 1 | sprout 1 | total 133 neurons
#   Batch 2059 | freeze 1 | sprout 1 | total 134 neurons
#   Batch 2079 | freeze 3 | sprout 3 | total 137 neurons
#   Batch 2119 | freeze 1 | sprout 1 | total 138 neurons
#   Batch 2139 | freeze 1 | sprout 1 | total 139 neurons
#   Batch 2159 | freeze 3 | sprout 3 | total 142 neurons
#   Batch 2199 | freeze 1 | sprout 1 | total 143 neurons
#   Batch 2219 | freeze 1 | sprout 1 | total 144 neurons
#   Batch 2239 | freeze 3 | sprout 3 | total 147 neurons
#   Batch 2279 | freeze 1 | sprout 1 | total 148 neurons
#   Batch 2299 | freeze 1 | sprout 1 | total 149 neurons
#   Batch 2319 | freeze 3 | sprout 3 | total 152 neurons
# End of Task 1 | frozen=147 plastic=5 total=152
#   Task 1: 98.0%
#
# --- Task 2/5  (Task 2) ---
#   Batch 2359 | freeze 1 | sprout 1 | total 153 neurons
#   Batch 2399 | freeze 1 | sprout 1 | total 154 neurons
#   Batch 2439 | freeze 1 | sprout 1 | total 155 neurons
#   Batch 2479 | freeze 2 | sprout 2 | total 157 neurons
#   Batch 2519 | freeze 2 | sprout 2 | total 159 neurons
#   Batch 2559 | freeze 3 | sprout 3 | total 162 neurons
#   Batch 2599 | freeze 2 | sprout 2 | total 164 neurons
#   Batch 2639 | freeze 3 | sprout 3 | total 167 neurons
#   Batch 2679 | freeze 2 | sprout 2 | total 169 neurons
#   Batch 2719 | freeze 3 | sprout 3 | total 172 neurons
#   Batch 2759 | freeze 2 | sprout 2 | total 174 neurons
#   Batch 2799 | freeze 3 | sprout 3 | total 177 neurons
#   Batch 2839 | freeze 2 | sprout 2 | total 179 neurons
#   Batch 2879 | freeze 3 | sprout 3 | total 182 neurons
#   Batch 2919 | freeze 2 | sprout 2 | total 184 neurons
#   Batch 2959 | freeze 3 | sprout 3 | total 187 neurons
#   Batch 2999 | freeze 2 | sprout 2 | total 189 neurons
#   Batch 3039 | freeze 3 | sprout 3 | total 192 neurons
#   Batch 3079 | freeze 2 | sprout 2 | total 194 neurons
#   Batch 3119 | freeze 3 | sprout 3 | total 197 neurons
#   Batch 3159 | freeze 2 | sprout 2 | total 199 neurons
#   Batch 3199 | freeze 3 | sprout 3 | total 202 neurons
#   Batch 3239 | freeze 2 | sprout 2 | total 204 neurons
#   Batch 3279 | freeze 3 | sprout 3 | total 207 neurons
#   Batch 3319 | freeze 2 | sprout 2 | total 209 neurons
#   Batch 3359 | freeze 3 | sprout 3 | total 212 neurons
#   Batch 3399 | freeze 2 | sprout 2 | total 214 neurons
#   Batch 3439 | freeze 3 | sprout 3 | total 217 neurons
#   Batch 3479 | freeze 2 | sprout 2 | total 219 neurons
#   Batch 3519 | freeze 3 | sprout 3 | total 222 neurons
#   Batch 3559 | freeze 2 | sprout 2 | total 224 neurons
#   Batch 3599 | freeze 3 | sprout 3 | total 227 neurons
#   Batch 3639 | freeze 2 | sprout 2 | total 229 neurons
#   Batch 3679 | freeze 3 | sprout 3 | total 232 neurons
#   Batch 3719 | freeze 2 | sprout 2 | total 234 neurons
#   Batch 3759 | freeze 3 | sprout 3 | total 237 neurons
#   Batch 3799 | freeze 2 | sprout 2 | total 239 neurons
#   Batch 3839 | freeze 3 | sprout 3 | total 242 neurons
#   Batch 3879 | freeze 2 | sprout 2 | total 244 neurons
#   Batch 3919 | freeze 3 | sprout 3 | total 247 neurons
#   Batch 3959 | freeze 2 | sprout 2 | total 249 neurons
#   Batch 3999 | freeze 3 | sprout 3 | total 252 neurons
#   Batch 4039 | freeze 2 | sprout 2 | total 254 neurons
#   Batch 4079 | freeze 3 | sprout 3 | total 257 neurons
#   Batch 4119 | freeze 2 | sprout 2 | total 259 neurons
#   Batch 4159 | freeze 3 | sprout 3 | total 262 neurons
#   Batch 4199 | freeze 2 | sprout 2 | total 264 neurons
#   Batch 4239 | freeze 3 | sprout 3 | total 267 neurons
#   Batch 4279 | freeze 2 | sprout 2 | total 269 neurons
#   Batch 4319 | freeze 3 | sprout 3 | total 272 neurons
#   Batch 4359 | freeze 2 | sprout 2 | total 274 neurons
#   Batch 4399 | freeze 3 | sprout 3 | total 277 neurons
#   Batch 4439 | freeze 2 | sprout 2 | total 279 neurons
#   Batch 4479 | freeze 3 | sprout 3 | total 282 neurons
#   Batch 4519 | freeze 2 | sprout 2 | total 284 neurons
#   Batch 4559 | freeze 3 | sprout 3 | total 287 neurons
#   Batch 4599 | freeze 2 | sprout 2 | total 289 neurons
#   Batch 4639 | freeze 3 | sprout 3 | total 292 neurons
#   Batch 4679 | freeze 2 | sprout 2 | total 294 neurons
# End of Task 2 | frozen=289 plastic=5 total=294
#   Task 1: 97.2%
#   Task 2: 95.7%
#
# --- Task 3/5  (Task 3) ---
#   Batch 4719 | freeze 1 | sprout 1 | total 295 neurons
#   Batch 4799 | freeze 5 | sprout 5 | total 300 neurons
#   Batch 4879 | freeze 5 | sprout 5 | total 305 neurons
#   Batch 4959 | freeze 5 | sprout 5 | total 310 neurons
#   Batch 5039 | freeze 5 | sprout 5 | total 315 neurons
#   Batch 5119 | freeze 5 | sprout 5 | total 320 neurons
#   Batch 5199 | freeze 5 | sprout 5 | total 325 neurons
#   Batch 5279 | freeze 5 | sprout 5 | total 330 neurons
#   Batch 5359 | freeze 5 | sprout 5 | total 335 neurons
#   Batch 5439 | freeze 5 | sprout 5 | total 340 neurons
#   Batch 5519 | freeze 5 | sprout 5 | total 345 neurons
#   Batch 5599 | freeze 5 | sprout 5 | total 350 neurons
#   Batch 5679 | freeze 5 | sprout 5 | total 355 neurons
#   Batch 5759 | freeze 5 | sprout 5 | total 360 neurons
#   Batch 5839 | freeze 5 | sprout 5 | total 365 neurons
#   Batch 5919 | freeze 5 | sprout 5 | total 370 neurons
#   Batch 5999 | freeze 5 | sprout 5 | total 375 neurons
#   Batch 6079 | freeze 5 | sprout 5 | total 380 neurons
#   Batch 6159 | freeze 5 | sprout 5 | total 385 neurons
#   Batch 6239 | freeze 5 | sprout 5 | total 390 neurons
#   Batch 6319 | freeze 5 | sprout 5 | total 395 neurons
#   Batch 6399 | freeze 5 | sprout 5 | total 400 neurons
#   Batch 6479 | freeze 5 | sprout 5 | total 405 neurons
#   Batch 6559 | freeze 5 | sprout 5 | total 410 neurons
#   Batch 6639 | freeze 5 | sprout 5 | total 415 neurons
#   Batch 6719 | freeze 5 | sprout 5 | total 420 neurons
#   Batch 6799 | freeze 5 | sprout 5 | total 425 neurons
#   Batch 6879 | freeze 5 | sprout 5 | total 430 neurons
#   Batch 6959 | freeze 5 | sprout 5 | total 435 neurons
#   Batch 7039 | freeze 5 | sprout 5 | total 440 neurons
# End of Task 3 | frozen=435 plastic=5 total=440
#   Task 1: 97.9%
#   Task 2: 95.0%
#   Task 3: 100.0%
#
# --- Task 4/5  (Task 4) ---
#   Batch 7119 | freeze 5 | sprout 5 | total 445 neurons
#   Batch 7199 | freeze 5 | sprout 5 | total 450 neurons
#   Batch 7279 | freeze 5 | sprout 5 | total 455 neurons
#   Batch 7359 | freeze 5 | sprout 5 | total 460 neurons
#   Batch 7439 | freeze 5 | sprout 5 | total 465 neurons
#   Batch 7519 | freeze 5 | sprout 5 | total 470 neurons
#   Batch 7599 | freeze 5 | sprout 5 | total 475 neurons
#   Batch 7679 | freeze 5 | sprout 5 | total 480 neurons
#   Batch 7759 | freeze 5 | sprout 5 | total 485 neurons
#   Batch 7839 | freeze 5 | sprout 5 | total 490 neurons
#   Batch 7919 | freeze 5 | sprout 5 | total 495 neurons
#   Batch 7999 | freeze 5 | sprout 5 | total 500 neurons
#   Batch 8079 | freeze 5 | sprout 5 | total 505 neurons
#   Batch 8159 | freeze 5 | sprout 5 | total 510 neurons
#   Batch 8239 | freeze 5 | sprout 5 | total 515 neurons
#   Batch 8319 | freeze 5 | sprout 5 | total 520 neurons
#   Batch 8399 | freeze 5 | sprout 5 | total 525 neurons
#   Batch 8479 | freeze 5 | sprout 5 | total 530 neurons
#   Batch 8559 | freeze 5 | sprout 5 | total 535 neurons
#   Batch 8639 | freeze 5 | sprout 5 | total 540 neurons
#   Batch 8719 | freeze 5 | sprout 5 | total 545 neurons
#   Batch 8799 | freeze 5 | sprout 5 | total 550 neurons
#   Batch 8879 | freeze 5 | sprout 5 | total 555 neurons
#   Batch 8959 | freeze 5 | sprout 5 | total 560 neurons
#   Batch 9039 | freeze 5 | sprout 5 | total 565 neurons
#   Batch 9119 | freeze 5 | sprout 5 | total 570 neurons
#   Batch 9199 | freeze 5 | sprout 5 | total 575 neurons
#   Batch 9279 | freeze 5 | sprout 5 | total 580 neurons
#   Batch 9359 | freeze 5 | sprout 5 | total 585 neurons
# End of Task 4 | frozen=580 plastic=5 total=585
#   Task 1: 92.1%
#   Task 2: 64.6%
#   Task 3: 79.7%
#   Task 4: 100.0%
#
# --- Task 5/5  (Task 5) ---
#   Batch 9439 | freeze 5 | sprout 5 | total 590 neurons
#   Batch 9519 | freeze 5 | sprout 5 | total 595 neurons
#   Batch 9599 | freeze 5 | sprout 5 | total 600 neurons
#   Batch 9679 | freeze 5 | sprout 5 | total 605 neurons
#   Batch 9759 | freeze 5 | sprout 5 | total 610 neurons
#   Batch 9839 | freeze 5 | sprout 5 | total 615 neurons
#   Batch 9919 | freeze 5 | sprout 5 | total 620 neurons
#   Batch 9999 | freeze 5 | sprout 5 | total 625 neurons
#   Batch 10079 | freeze 5 | sprout 5 | total 630 neurons
#   Batch 10159 | freeze 5 | sprout 5 | total 635 neurons
#   Batch 10239 | freeze 5 | sprout 5 | total 640 neurons
#   Batch 10319 | freeze 5 | sprout 5 | total 645 neurons
#   Batch 10399 | freeze 5 | sprout 5 | total 650 neurons
#   Batch 10479 | freeze 5 | sprout 5 | total 655 neurons
#   Batch 10559 | freeze 5 | sprout 5 | total 660 neurons
#   Batch 10639 | freeze 5 | sprout 5 | total 665 neurons
#   Batch 10719 | freeze 5 | sprout 5 | total 670 neurons
#   Batch 10799 | freeze 5 | sprout 5 | total 675 neurons
#   Batch 10879 | freeze 5 | sprout 5 | total 680 neurons
#   Batch 10959 | freeze 5 | sprout 5 | total 685 neurons
#   Batch 11039 | freeze 5 | sprout 5 | total 690 neurons
#   Batch 11119 | freeze 5 | sprout 5 | total 695 neurons
#   Batch 11199 | freeze 5 | sprout 5 | total 700 neurons
#   Batch 11279 | freeze 5 | sprout 5 | total 705 neurons
#   Batch 11359 | freeze 5 | sprout 5 | total 710 neurons
#   Batch 11439 | freeze 5 | sprout 5 | total 715 neurons
#   Batch 11519 | freeze 5 | sprout 5 | total 720 neurons
#   Batch 11599 | freeze 5 | sprout 5 | total 725 neurons
#   Batch 11679 | freeze 5 | sprout 5 | total 730 neurons
# End of Task 5 | frozen=725 plastic=5 total=730
#   Task 1: 92.1%
#   Task 2: 64.5%
#   Task 3: 79.6%
#   Task 4: 99.9%
#   Task 5: 99.5%
#
# Final: 730 neurons  (725 frozen)
# Growth events: 231

# %% [markdown]
# ## Step 3 — Analysis & Insight Plots

# %%
# ── ANALYSIS: tau_high_mode comparison + output vs hidden grads ───────
logs = mon.log
if not logs:
    print("No logs yet — run the training cell first.")
else:
    batches  = [s['batch']     for s in logs]
    tau_vals = [s['tau_high']  for s in logs]
    n_frozen = [s['n_frozen']  for s in logs]
    n_plastic= [s['n_plastic'] for s in logs]
    n_sprout = [s['n_sprout_now'] for s in logs]
    n_freeze = [s['n_freeze_now'] for s in logs]

    # Pad jagged arrays (neuron count grows over time) to max length with NaN
    max_n = max(len(s['grad_mag']) for s in logs)
    def _pad(lst):
        return lst + [float('nan')] * (max_n - len(lst))
    gm_arr = np.array([_pad(s['grad_mag'])     for s in logs])
    og_arr = np.array([_pad(s['out_grad_mag']) for s in logs])
    cf_arr = np.array([_pad(s['conflict']) for s in logs])

    fig, axes = plt.subplots(3, 2, figsize=(18, 14))
    fig.suptitle(f"NSI Analysis  [tau_high_mode={CFG['tau_high_mode']}]",
                 fontsize=15, fontweight='bold')

    # P1: tau_high evolution
    ax = axes[0, 0]
    ax.plot(batches, tau_vals, 'b-', linewidth=2)
    if CFG['tau_high_mode'] == 'percentile':
        ax.set_title(f"tau_high (percentile, p={CFG['tau_high_pct']})")
    else:
        ax.axhline(CFG['tau_high_abs'], color='r', linestyle='--')
        ax.set_title("tau_high (absolute, fixed)")
    ax.set_ylabel('tau_high value')
    ax.grid(alpha=0.3)

    # P2: frozen/plastic count
    ax = axes[0, 1]
    ax.stackplot(batches, n_frozen, n_plastic, labels=['FROZEN','PLASTIC'],
                 colors=['#d62728','#1f77b4'], alpha=0.7)
    ax.set_title('Neuron State Counts Over Time')
    ax.set_ylabel('Neurons')
    ax.legend(loc='upper left')
    ax.grid(alpha=0.3)

    # P3: hidden grad_mag heatmap
    ax = axes[1, 0]
    im = ax.imshow(gm_arr.T, aspect='auto', cmap='hot',
                   extent=[batches[0], batches[-1], 0, gm_arr.shape[1]])
    plt.colorbar(im, ax=ax)
    ax.set_title('Hidden grad_mag per neuron (heatmap)')
    ax.set_ylabel('Neuron index')
    ax.set_xlabel('Batch')

    # P4: output grad_mag heatmap
    ax = axes[1, 1]
    im = ax.imshow(og_arr.T, aspect='auto', cmap='hot',
                   extent=[batches[0], batches[-1], 0, og_arr.shape[1]])
    plt.colorbar(im, ax=ax)
    ax.set_title('Output grad_mag per neuron (heatmap)\n[track_output_grads=True]')
    ax.set_ylabel('Neuron index')
    ax.set_xlabel('Batch')

    # P5: SI contribution heatmap (diverging)
    ax = axes[2, 0]
    vmax = np.abs(cf_arr).max() + 1e-8
    im = ax.imshow(cf_arr.T, aspect='auto', cmap='RdBu',
                   vmin=-vmax, vmax=vmax,
                   extent=[batches[0], batches[-1], 0, cf_arr.shape[1]])
    plt.colorbar(im, ax=ax)
    ax.set_title('Gradient Conflict Index  (red = struggling)')
    ax.set_ylabel('Neuron index')
    ax.set_xlabel('Batch')

    # P6: Task accuracy curves
    ax = axes[2, 1]
    colors = ['b','g','r','c','m']
    for tid in range(5):
        xs, ys = [], []
        for step, accs in enumerate(dynamic_accs):
            if tid < len(accs):
                xs.append(step+1); ys.append(accs[tid]*100)
        if xs:
            ax.plot(xs, ys, f'{colors[tid]}o-', label=f'Task {tid+1}', linewidth=2)
    ax.set_ylim(0, 105)
    ax.set_title('Task Accuracy Over Time')
    ax.set_xlabel('Tasks Completed')
    ax.set_ylabel('Accuracy (%)')
    ax.legend(fontsize=8)
    ax.grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig('nsi_analysis.png', dpi=150, bbox_inches='tight')
    plt.show()

    # Correlation: does output grad predict forgetting?
    print("\n=== Output vs Hidden Grad Correlation ===")
    late_h = gm_arr[-10:].mean(0)   # late hidden grad per neuron
    late_o = og_arr[-10:].mean(0)   # late output grad per neuron
    if late_h.std() > 0 and late_o.std() > 0:
        corr = np.corrcoef(late_h, late_o)[0,1]
        print(f"  Pearson correlation (hidden vs output grad_mag): {corr:.3f}")
        print("  -> Close to 1.0: output grads add no new info (active-class masking works)")
        print("  -> Far from 1.0: output grads carry different signal (worth tracking)")
    
    print(f"\n=== tau_high_mode='{CFG['tau_high_mode']}' summary ===")
    print(f"  tau_high range: [{min(tau_vals):.5f}, {max(tau_vals):.5f}]")
    print(f"  Total growth events: {len(growth_events)}")
    print(f"  Final neuron count: {net.active_neurons}")
# Out:
# === Output vs Hidden Grad Correlation ===
#
# === tau_high_mode='percentile' summary ===
#   tau_high range: [0.00000, 1000000000.00000]
#   Total growth events: 231
#   Final neuron count: 730

# %% [markdown]
# ## Step 4 — Experiment: percentile vs absolute tau_high

# %%
# ── EXPERIMENT: run percentile mode vs absolute mode side-by-side ────
# Set tau_high_abs from diagnostic cell first, then run this.
# This lets you directly compare the two tau_high strategies.

def run_experiment(tau_high_mode, tau_high_pct=0.70, tau_high_abs=None, label=''):
    net_  = DynamicBrain(input_dim=784, seed_neurons=10).to(device)
    opt_  = torch.optim.Adam(net_.parameters(), lr=0.003)
    crit_ = nn.CrossEntropyLoss()
    mon_  = NeuronHealthMonitor(
        num_neurons=10, device=device,
        alpha=0.05, check_interval=20, patience=3, min_age=40,
        tau_low=0.001,
        tau_high_mode=tau_high_mode,
        tau_high_pct=tau_high_pct,
        tau_high_abs=tau_high_abs,
        tau_conflict=0.5,
        track_output_grads=True,
    )
    accs_hist = []

    for task_idx, (Xtr_, ytr_) in enumerate(tasks_train):
        active_classes = [task_idx*2, task_idx*2+1]
        for epoch in range(3):
            for i in range(0, Xtr_.size(0), 64):
                bx = Xtr_[i:i+64].to(device); by = ytr_[i:i+64].to(device)
                if bx.size(0) < 16: continue
                net_.zero_grad()
                pred = net_(bx)
                lm   = torch.ones_like(pred, dtype=torch.bool)
                lm[:, active_classes] = False
                pred[lm] = -float('inf')
                loss = crit_(pred, by)
                loss.backward()
                hg = net_.hidden_W.grad.clone()
                og = net_.out_W.grad.clone()
                mon_.pre_step(net_)
                net_.zero_frozen_grads()
                opt_.step()
                mon_.post_step(net_, hg, og)
                if mon_.batch_no % 20 == 0:
                    to_freeze, n_sprout, _ = mon_.check_health(net_)
                    if to_freeze or n_sprout > 0:
                        net_.grow_and_freeze(to_freeze, n_sprout)
                        mon_.expand(n_sprout)
                        opt_ = torch.optim.Adam(net_.parameters(), lr=0.003)
        accs_hist.append(evaluate(net_, tasks_test, task_idx))

    print(f"[{label}] final neurons={net_.active_neurons}  "
          f"frozen={sum(1 for s in net_.neuron_states if s=='FROZEN')}")
    return accs_hist, mon_.log

print("Run with:")
print("  accs_pct, log_pct = run_experiment('percentile', tau_high_pct=0.70, label='percentile-p70')")
print("  accs_abs, log_abs = run_experiment('absolute',   tau_high_abs=<from diagnostic>, label='absolute')")
print()
print("Then compare accs_pct vs accs_abs on a plot.")
# Out:
# Run with:
#   accs_pct, log_pct = run_experiment('percentile', tau_high_pct=0.70, label='percentile-p70')
#   accs_abs, log_abs = run_experiment('absolute',   tau_high_abs=<from diagnostic>, label='absolute')
#
# Then compare accs_pct vs accs_abs on a plot.

# %% [markdown]
# ## Step 5 — Hyperparameter Grid Search
# Sweep over `seed_neurons`, `k_frozen`, and `k_plastic` to find the optimal balance between high accuracy and small network size.
